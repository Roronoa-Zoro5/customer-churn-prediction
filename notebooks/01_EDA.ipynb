# %%
import numpy as np
# import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

data = df.copy()

data.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1243  5552-ZNFSJ    Male              0      No         No       1
# 2365  7268-IGMFD    Male              1      No         No      18
# 3057  7319-ZNRTR    Male              0     Yes        Yes      25
# 215   0699-NDKJM  Female              0     Yes         No      57
# 2861  2004-OCQXK  Female              0      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1243          Yes                No             DSL                   No  ...
# 2365          Yes               Yes     Fiber optic                   No  ...
# 3057          Yes                No              No  No internet service  ...
# 215            No  No phone service             DSL                  Yes  ...
# 2861          Yes                No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
# print(df['SeniorCitizen'].value_counts())     # bool
# print(df['MultipleLines'].value_counts())       # categorical, yes, no, no phone service
# print(df['InternetService'].value_counts())       # 3 categories
# print(df['OnlineSecurity'].value_counts())       # 3 categories
print(data['PhoneService'].value_counts())         # 3 categories
print(data.info())
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
# ...

# %%
print(data.shape)
data.isnull().sum()
# Out:
# (7043, 21)
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# import seaborn as sns
# sns.violinplot(data=df, x='PaymentMethod', y='Churn', )

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python313\python.exe

# %%
# sns.scatterplot(data=data, x='')
