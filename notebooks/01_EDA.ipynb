# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

data = df.copy()

data.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1416  4859-ZSRDZ  Female              0     Yes        Yes      58
# 2357  9251-WNSOD  Female              0     Yes         No      67
# 1040  1236-WFCDV    Male              1      No         No      14
# 3674  7825-GKXMW  Female              0      No         No       1
# 6220  6434-TTGJP    Male              0     Yes        Yes      10
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1416           No  No phone service             DSL             No  ...
# 2357          Yes               Yes             DSL            Yes  ...
# 1040          Yes                No     Fiber optic             No  ...
# 3674          Yes                No             DSL             No  ...
# 6220           No  No phone service             DSL            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 1416              Yes         Yes         Yes             Yes        Two year
# 2357              Yes          No          No             Yes        One year
# 1040               No          No         Yes             Yes  Month-to-month
# 3674               No          No          No              No  Month-to-month
# 6220              Yes         Yes          No             Yes        Two year
#
#      PaperlessBilling            PaymentMethod MonthlyCharges  TotalCharges  \
# 1416              Yes  Credit card (automatic)          55.50        3166.9
# 2357               No             Mailed check          75.10       5064.45
# 1040               No  Credit card (automatic)          90.45        1266.1
# 3674               No         Electronic check          45.80          45.8
# 6220               No  Credit card (automatic)          53.70           521
#
#      Churn
# 1416    No
# 2357    No
# 1040   Yes
# 3674   Yes
# 6220    No
#
# [5 rows x 21 columns]

# %%
# print(df['SeniorCitizen'].value_counts())     # bool
# print(df['MultipleLines'].value_counts())       # categorical, yes, no, no phone service
# print(df['InternetService'].value_counts())       # 3 categories
# print(df['OnlineSecurity'].value_counts())       # 3 categories
print(data['PhoneService'].value_counts())         # 3 categories
print(data.info())
# Out:
# PhoneService
# Yes    6361
# No      682
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB
# None

# %%
print(data.shape)
data.isnull().sum()
# Out:
# (7043, 21)
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
import seaborn as sns
sns.violinplot(data=df, x='PaymentMethod', y='Churn')
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='Churn'>
